# %%
import numpy as np
from ts import acf

# %%
a = np.random.normal(0, 1, 100).tolist()

# %% [markdown]
# # Autocorrelation Function

# %% [markdown]
# ## Constant Variance

# %%
normal = acf(a, 30, barlett_ci=False)

# %% [markdown]
# ## Variance from Barlett's Equation

# %%
non_normal = acf(a, 30, barlett_ci=True)
